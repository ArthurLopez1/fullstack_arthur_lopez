# %% [markdown]
# # EDA on Public Transport Trafiklab API

# %%
from dotenv import load_dotenv
import os 
import requests

load_dotenv()

API_KEY = os.getenv("API_KEY")

url = f"https://api.resrobot.se/v2.1/trip?format=json&originId=740000001&destId=740000003&passlist=true&showPassingPoints=true&accessId={API_KEY}"

response = requests.get(url)
result = response.json()
result.keys()
# Out:
# dict_keys(['Trip', 'ResultStatus', 'TechnicalMessages', 'serverVersion', 'dialectVersion', 'planRtTs', 'requestId', 'scrB', 'scrF'])

# %%
len(result["Trip"])
# Out:
# 7

# %%
result["ResultStatus"], result["TechnicalMessages"]
# Out:
# ({'timeDiffCritical': False},
#  {'TechnicalMessage': [{'value': '2025-01-21 12:13:20', 'key': 'requestTime'},
#    {'value': 'ttp=16439#16603 plancode0=0pi2w planid=1737434182 planid0=1737434182 planid_adr=1479298166 plancode_adr=q0r10 srvv=5.45.SAMTRAFIKEN.15.0.1 (customer/hcusamtrafiken/release/2023.10.0) [2023-10-19] tlibv=TRFVER: rel/pproxy/4.00.0 2022-10-24 18:24:51 +0200 Relay_EnrichmentProxy v1 jno=1',
#     'key': 'backendInfo'}]})

# %% [markdown]
# ### Function to get a trip

# %%
def get_trips(origin_id=740000001, destination_id="740098001"):
    """origin_id and destination_id can be found from Stop lookup API"""
    url = f"https://api.resrobot.se/v2.1/trip?format=json&originId=740000001&destId=740000003&passlist=true&showPassingPoints=true&accessId={API_KEY}"

    try:
        response = requests.get(url)
        response.raise_for_status()
            
        return response.json()
        
    except requests.exceptions.RequestException as err:
        print(f"Network or HTTP error: {err}")

result = get_trips()
result.keys()
# Out:
# dict_keys(['Trip', 'ResultStatus', 'TechnicalMessages', 'serverVersion', 'dialectVersion', 'planRtTs', 'requestId', 'scrB', 'scrF'])

# %%
example_trip = result["Trip"][0]
example_trip
# Out:
# {'Origin': {'name': 'Stockholm Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#   'extId': '740000001',
#   'lon': 18.058151,
#   'lat': 59.330136,
#   'routeIdx': 0,
#   'prognosisType': 'PROGNOSED',
#   'time': '12:14:00',
#   'date': '2025-01-21',
#   'minimumChangeDuration': 'PT20M'},
#  'Destination': {'name': 'Malmö Centralstation',
#   'type': 'ST',
#   'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#   'extId': '740000003',
#   'lon': 13.00091,
#   'lat': 55.609456,
#   'routeIdx': 12,
#   'prognosisType': 'PROGNOSED',
#   'time': '20:48:00',
#   'date': '2025-01-21',
#   'minimumChangeDuration': 'PT15M'},
#  'ServiceDays': [{'planningPeriodBegin': '2025-01-02',
#    'planningPeriodEnd': '2025-06-15',
#    'sDaysR': 'inte varje dag',
#    'sDaysI': '21. jan t o m 5. jun 2025 mån - fre; utom 14. t o m 21. apr 2025, 1., 29., 30. maj',
#    'sDaysB': '00013E7CF9F3E7CF9F3E7CF9F003CE9F3E7CE1E000'}],
#  'LegList': {'Leg': [{'Origin': {'name': 'Stockholm Centralstation',
#      'type': 'ST',
#      'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#      'extId': '740000001',
#      'lon': 18.058151,
#      'lat': 59.330136,
#      'routeIdx': 0,
#      'prognosisType': 'PROGNOSED',
#      'time': '12:14:00',
#      'date': '2025-01-21',
#      'minimumChangeDuration': 'PT20M'},
#     'Destination': {'name': 'Göteborg Centralstation',
#      'type': 'ST',
#      'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#      'extId': '740000002',
#      'lon': 11.973479,
#      'lat': 57.708895,
#      'routeIdx': 18,
#      'prognosisType': 'PROGNOSED',
#      'time': '17:00:00',
#      'date': '2025-01-21',
#      'minimumChangeDuration': 'PT15M'},
#     'Notes': {'Note': [{'value': '2 kl har ej reservering',
#        'key': 'AB',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 5,
#        'txtN': '2 kl har ej reservering'},
#       {'value': '2 kl har ej reservering',
#        'key': 'AB',
#        'type': 'A',
#        'routeIdxFrom': 7,
#        'routeIdxTo': 10,
#        'txtN': '2 kl har ej reservering'},
#       {'value': '2 kl har ej reservering',
#        'key': 'AB',
#        'type': 'A',
#        'routeIdxFrom': 13,
#        'routeIdxTo': 18,
#        'txtN': '2 kl har ej reservering'},
#       {'value': 'Obligatorisk platsbokning',
#        'key': 'AF',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 18,
#        'txtN': 'Obligatorisk platsbokning'},
#       {'value': 'Rullstolslyft',
#        'key': 'AN',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 18,
#        'txtN': 'Rullstolslyft'},
#       {'value': 'WiFi',
#        'key': 'AW',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 18,
#        'txtN': 'WiFi'},
#       {'value': 'EU förordning 2021/782',
#        'key': 'EJ',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 18,
#        'txtN': 'EU förordning 2021/782'},
#       {'value': 'Servering finns ej',
#        'key': 'SI',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 18,
#        'txtN': 'Servering finns ej'}]},
#     'JourneyDetailRef': {'ref': '1|132762|0|1|21012025'},
#     'JourneyStatus': 'P',
#     'Product': [{'icon': {'res': 'prod_gen'},
#       'operatorInfo': {'name': 'SJ',
#        'nameS': '74',
#        'nameN': '74',
#        'nameL': 'SJ',
#        'id': '74'},
#       'name': 'Regional Tåg 173',
#       'internalName': 'Regional Tåg 173',
#       'displayNumber': '173',
#       'num': '173',
#       'line': '173',
#       'lineId': '1074017300001',
#       'catOut': 'JRE',
#       'catIn': 'JRE',
#       'catCode': '2',
#       'cls': '4',
#       'catOutS': 'JRE',
#       'catOutL': 'Regional Tåg',
#       'operatorCode': '74',
#       'operator': 'SJ',
#       'admin': '074___',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 18,
#       'matchId': '173;173;5647'}],
#     'Stops': {'Stop': [{'name': 'Stockholm Centralstation',
#        'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#        'extId': '740000001',
#        'routeIdx': 0,
#        'lon': 18.058151,
#        'lat': 59.330136,
#        'depPrognosisType': 'PROGNOSED',
#        'depTime': '12:14:00',
#        'depDate': '2025-01-21',
#        'depDir': 'Göteborg Centralstation',
#        'minimumChangeDuration': 'PT20M'},
#       {'Notes': {'Note': [{'value': 'Stannar endast för påstigande',
#           'key': 'text.realtime.stop.exit.disabled',
#           'type': 'R',
#           'txtN': 'Stannar endast för påstigande'}]},
#        'name': 'Sundbyberg station',
#        'id': 'A=1@O=Sundbyberg station@X=17970938@Y=59361032@U=1@L=740000773@',
#        'extId': '740000773',
#        'routeIdx': 1,
#        'lon': 17.970938,
#        'lat': 59.361032,
#        'depTime': '12:23:00',
#        'depDate': '2025-01-21',
#        'alighting': False,
#        'minimumChangeDuration': 'PT10M'},
#       {'name': 'Bålsta station (Håbo kn)',
#        'id': 'A=1@O=Bålsta station (Håbo kn)@X=17532813@Y=59568754@U=1@L=740000660@',
#        'extId': '740000660',
#        'routeIdx': 2,
#        'lon': 17.532813,
#        'lat': 59.568754,
#        'depTime': '12:41:00',
#        'depDate': '2025-01-21',
#        'arrTime': '12:41:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT10M'},
#       {'name': 'Enköping station',
#        'id': 'A=1@O=Enköping station@X=17086741@Y=59644327@U=1@L=740000072@',
#        'extId': '740000072',
#        'routeIdx': 3,
#        'lon': 17.086741,
#        'lat': 59.644327,
#        'depTime': '12:54:00',
#        'depDate': '2025-01-21',
#        'arrTime': '12:54:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT8M'},
#       {'name': 'Västerås Centralstation',
#        'id': 'A=1@O=Västerås Centralstation@X=16551712@Y=59607705@U=1@L=740000099@',
#        'extId': '740000099',
#        'routeIdx': 4,
#        'lon': 16.551712,
#        'lat': 59.607705,
#        'depTime': '13:11:00',
#        'depDate': '2025-01-21',
#        'arrTime': '13:09:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT8M'},
#       {'name': 'Köping station',
#        'id': 'A=1@O=Köping station@X=16004215@Y=59506675@U=1@L=740000167@',
#        'extId': '740000167',
#        'routeIdx': 5,
#        'lon': 16.004215,
#        'lat': 59.506675,
#        'depTime': '13:28:00',
#        'depDate': '2025-01-21',
#        'arrTime': '13:28:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT5M'},
#       {'name': 'Arboga station',
#        'id': 'A=1@O=Arboga station@X=15841061@Y=59397105@U=1@L=740000262@',
#        'extId': '740000262',
#        'routeIdx': 6,
#        'lon': 15.841061,
#        'lat': 59.397105,
#        'depTime': '13:40:00',
#        'depDate': '2025-01-21',
#        'arrTime': '13:39:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT5M'},
#       {'name': 'Örebro Centralstation',
#        'id': 'A=1@O=Örebro Centralstation@X=15211348@Y=59278942@U=1@L=740000133@',
#        'extId': '740000133',
#        'routeIdx': 7,
#        'lon': 15.211348,
#        'lat': 59.278942,
#        'depTime': '14:14:00',
#        'depDate': '2025-01-21',
#        'arrTime': '14:01:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT10M'},
#       {'name': 'Örebro Södra station',
#        'id': 'A=1@O=Örebro Södra station@X=15202332@Y=59269989@U=1@L=740000361@',
#        'extId': '740000361',
#        'routeIdx': 8,
#        'lon': 15.202332,
#        'lat': 59.269989,
#        'depTime': '14:17:00',
#        'depDate': '2025-01-21',
#        'arrTime': '14:17:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT1H30M'},
#       {'name': 'Kumla station',
#        'id': 'A=1@O=Kumla station@X=15140280@Y=59126377@U=1@L=740000192@',
#        'extId': '740000192',
#        'routeIdx': 9,
#        'lon': 15.14028,
#        'lat': 59.126377,
#        'depTime': '14:27:00',
#        'depDate': '2025-01-21',
#        'arrTime': '14:27:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT10M'},
#       {'name': 'Hallsberg station',
#        'id': 'A=1@O=Hallsberg station@X=15110391@Y=59066698@U=1@L=740000077@',
#        'extId': '740000077',
#        'routeIdx': 10,
#        'lon': 15.110391,
#        'lat': 59.066698,
#        'depTime': '14:40:00',
#        'depDate': '2025-01-21',
#        'arrTime': '14:35:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT10M'},
#       {'name': 'Laxå station',
#        'id': 'A=1@O=Laxå station@X=14616658@Y=58989391@U=1@L=740000194@',
#        'extId': '740000194',
#        'routeIdx': 11,
#        'lon': 14.616658,
#        'lat': 58.989391,
#        'depTime': '14:57:00',
#        'depDate': '2025-01-21',
#        'arrTime': '14:57:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT10M'},
#       {'name': 'Töreboda station',
#        'id': 'A=1@O=Töreboda station@X=14128391@Y=58706024@U=1@L=740000183@',
#        'extId': '740000183',
#        'routeIdx': 12,
#        'lon': 14.128391,
#        'lat': 58.706024,
#        'depTime': '15:20:00',
#        'depDate': '2025-01-21',
#        'arrTime': '15:20:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT8M'},
#       {'name': 'Skövde Centralstation',
#        'id': 'A=1@O=Skövde Centralstation@X=13853195@Y=58390898@U=1@L=740000008@',
#        'extId': '740000008',
#        'routeIdx': 13,
#        'lon': 13.853195,
#        'lat': 58.390898,
#        'depTime': '15:36:00',
#        'depDate': '2025-01-21',
#        'arrTime': '15:35:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT10M'},
#       {'name': 'Falköping Centralstation',
#        'id': 'A=1@O=Falköping Centralstation@X=13553791@Y=58176101@U=1@L=740000060@',
#        'extId': '740000060',
#        'routeIdx': 14,
#        'lon': 13.553791,
#        'lat': 58.176101,
#        'depTime': '15:52:00',
#        'depDate': '2025-01-21',
#        'arrTime': '15:51:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT8M'},
#       {'name': 'Herrljunga station',
#        'id': 'A=1@O=Herrljunga station@X=13021279@Y=58079188@U=1@L=740000040@',
#        'extId': '740000040',
#        'routeIdx': 15,
#        'lon': 13.021279,
#        'lat': 58.079188,
#        'depTime': '16:06:00',
#        'depDate': '2025-01-21',
#        'arrTime': '16:06:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT8M'},
#       {'name': 'Vårgårda station',
#        'id': 'A=1@O=Vårgårda station@X=12810285@Y=58031204@U=1@L=740000569@',
#        'extId': '740000569',
#        'routeIdx': 16,
#        'lon': 12.810285,
#        'lat': 58.031204,
#        'depTime': '16:14:00',
#        'depDate': '2025-01-21',
#        'arrTime': '16:14:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT10M'},
#       {'name': 'Alingsås station',
#        'id': 'A=1@O=Alingsås station@X=12532491@Y=57926857@U=1@L=740000018@',
#        'extId': '740000018',
#        'routeIdx': 17,
#        'lon': 12.532491,
#        'lat': 57.926857,
#        'depTime': '16:24:00',
#        'depDate': '2025-01-21',
#        'arrTime': '16:24:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT7M'},
#       {'name': 'Göteborg Centralstation',
#        'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#        'extId': '740000002',
#        'routeIdx': 18,
#        'lon': 11.973479,
#        'lat': 57.708895,
#        'arrPrognosisType': 'PROGNOSED',
#        'arrTime': '17:00:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT15M'}]},
#     'JourneyDetail': {'ref': '1|132762|0|1|21012025',
#      'dayOfOperation': '2025-01-21'},
#     'id': '0',
#     'idx': 0,
#     'name': 'Regional Tåg 173',
#     'number': '173',
#     'category': 'JRE',
#     'type': 'JNY',
#     'reachable': True,
#     'waitingState': 'UNDEF',
#     'direction': 'Göteborg Centralstation',
#     'directionFlag': '1',
#     'duration': 'PT4H46M',
#     'minimumChangeDuration': 'PT15M'},
#    {'Origin': {'name': 'Göteborg Centralstation',
#      'type': 'ST',
#      'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#      'extId': '740000002',
#      'lon': 11.973479,
#      'lat': 57.708895,
#      'routeIdx': 0,
#      'prognosisType': 'PROGNOSED',
#      'time': '17:40:00',
#      'date': '2025-01-21',
#      'minimumChangeDuration': 'PT15M'},
#     'Destination': {'name': 'Malmö Centralstation',
#      'type': 'ST',
#      'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#      'extId': '740000003',
#      'lon': 13.00091,
#      'lat': 55.609456,
#      'routeIdx': 12,
#      'prognosisType': 'PROGNOSED',
#      'time': '20:48:00',
#      'date': '2025-01-21',
#      'minimumChangeDuration': 'PT15M'},
#     'Notes': {'Note': [{'value': 'Ej reservering',
#        'key': 'AE',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 12,
#        'txtN': 'Ej reservering'},
#       {'value': 'Rullstolslyft',
#        'key': 'AN',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 12,
#        'txtN': 'Rullstolslyft'},
#       {'value': 'EU förordning 2021/782',
#        'key': 'EJ',
#        'type': 'A',
#        'routeIdxFrom': 0,
#        'routeIdxTo': 12,
#        'txtN': 'EU förordning 2021/782'}]},
#     'JourneyDetailRef': {'ref': '1|132477|0|1|21012025'},
#     'JourneyStatus': 'P',
#     'Product': [{'icon': {'res': 'prod_gen'},
#       'operatorInfo': {'name': 'Öresundståg',
#        'nameS': '300',
#        'nameN': '300',
#        'nameL': 'Öresundståg',
#        'id': '300'},
#       'name': 'Regional Tåg 1135',
#       'internalName': 'Regional Tåg 1135',
#       'displayNumber': '1135',
#       'num': '1135',
#       'line': '1135',
#       'lineId': '1300080400036',
#       'catOut': 'JRE',
#       'catIn': 'JRE',
#       'catCode': '2',
#       'cls': '4',
#       'catOutS': 'JRE',
#       'catOutL': 'Regional Tåg',
#       'operatorCode': '300',
#       'operator': 'Öresundståg',
#       'admin': '300___',
#       'routeIdxFrom': 0,
#       'routeIdxTo': 12,
#       'matchId': '11159;804;1135'}],
#     'Stops': {'Stop': [{'name': 'Göteborg Centralstation',
#        'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#        'extId': '740000002',
#        'routeIdx': 0,
#        'lon': 11.973479,
#        'lat': 57.708895,
#        'depPrognosisType': 'PROGNOSED',
#        'depTime': '17:40:00',
#        'depDate': '2025-01-21',
#        'depDir': 'Köpenhamn Österport (Danmark)',
#        'minimumChangeDuration': 'PT15M'},
#       {'name': 'Mölndal station',
#        'id': 'A=1@O=Mölndal station@X=12018722@Y=57655958@U=1@L=740000315@',
#        'extId': '740000315',
#        'routeIdx': 1,
#        'lon': 12.018722,
#        'lat': 57.655958,
#        'depTime': '17:48:00',
#        'depDate': '2025-01-21',
#        'arrTime': '17:48:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT9M'},
#       {'name': 'Kungsbacka station',
#        'id': 'A=1@O=Kungsbacka station@X=12079614@Y=57490556@U=1@L=740000161@',
#        'extId': '740000161',
#        'routeIdx': 2,
#        'lon': 12.079614,
#        'lat': 57.490556,
#        'depTime': '17:59:00',
#        'depDate': '2025-01-21',
#        'arrTime': '17:59:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT5M'},
#       {'name': 'Varberg station',
#        'id': 'A=1@O=Varberg station@X=12248081@Y=57109378@U=1@L=740000110@',
#        'extId': '740000110',
#        'routeIdx': 3,
#        'lon': 12.248081,
#        'lat': 57.109378,
#        'depTime': '18:29:00',
#        'depDate': '2025-01-21',
#        'arrTime': '18:25:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT5M'},
#       {'name': 'Falkenberg station',
#        'id': 'A=1@O=Falkenberg station@X=12507555@Y=56919768@U=1@L=740001579@',
#        'extId': '740001579',
#        'routeIdx': 4,
#        'lon': 12.507555,
#        'lat': 56.919768,
#        'depTime': '18:45:00',
#        'depDate': '2025-01-21',
#        'arrTime': '18:45:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT4M'},
#       {'name': 'Halmstad Centralstation',
#        'id': 'A=1@O=Halmstad Centralstation@X=12864840@Y=56669275@U=1@L=740000080@',
#        'extId': '740000080',
#        'routeIdx': 5,
#        'lon': 12.86484,
#        'lat': 56.669275,
#        'depTime': '19:13:00',
#        'depDate': '2025-01-21',
#        'arrTime': '19:03:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT10M'},
#       {'name': 'Laholm station',
#        'id': 'A=1@O=Laholm station@X=12999606@Y=56501905@U=1@L=740000058@',
#        'extId': '740000058',
#        'routeIdx': 6,
#        'lon': 12.999606,
#        'lat': 56.501905,
#        'depTime': '19:25:00',
#        'depDate': '2025-01-21',
#        'arrTime': '19:25:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT9M'},
#       {'name': 'Båstad station',
#        'id': 'A=1@O=Båstad station@X=12906991@Y=56431834@U=1@L=740001603@',
#        'extId': '740001603',
#        'routeIdx': 7,
#        'lon': 12.906991,
#        'lat': 56.431834,
#        'depTime': '19:32:00',
#        'depDate': '2025-01-21',
#        'arrTime': '19:32:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT4M'},
#       {'name': 'Ängelholm station',
#        'id': 'A=1@O=Ängelholm station@X=12854197@Y=56245200@U=1@L=740000064@',
#        'extId': '740000064',
#        'routeIdx': 8,
#        'lon': 12.854197,
#        'lat': 56.2452,
#        'depTime': '19:43:00',
#        'depDate': '2025-01-21',
#        'arrTime': '19:43:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT10M'},
#       {'name': 'Helsingborg Centralstation',
#        'id': 'A=1@O=Helsingborg Centralstation@X=12694261@Y=56044408@U=1@L=740000044@',
#        'extId': '740000044',
#        'routeIdx': 9,
#        'lon': 12.694261,
#        'lat': 56.044408,
#        'depTime': '20:07:00',
#        'depDate': '2025-01-21',
#        'arrTime': '20:04:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT9M'},
#       {'name': 'Landskrona station',
#        'id': 'A=1@O=Landskrona station@X=12857406@Y=55878898@U=1@L=740001554@',
#        'extId': '740001554',
#        'routeIdx': 10,
#        'lon': 12.857406,
#        'lat': 55.878898,
#        'depTime': '20:19:00',
#        'depDate': '2025-01-21',
#        'arrTime': '20:19:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT9M'},
#       {'name': 'Lund Centralstation',
#        'id': 'A=1@O=Lund Centralstation@X=13186897@Y=55708094@U=1@L=740000120@',
#        'extId': '740000120',
#        'routeIdx': 11,
#        'lon': 13.186897,
#        'lat': 55.708094,
#        'depTime': '20:38:00',
#        'depDate': '2025-01-21',
#        'arrTime': '20:36:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT10M'},
#       {'name': 'Malmö Centralstation',
#        'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#        'extId': '740000003',
#        'routeIdx': 12,
#        'lon': 13.00091,
#        'lat': 55.609456,
#        'arrTime': '20:48:00',
#        'arrDate': '2025-01-21',
#        'minimumChangeDuration': 'PT15M'}]},
#     'JourneyDetail': {'ref': '1|132477|0|1|21012025',
#      'dayOfOperation': '2025-01-21'},
#     'id': '1',
#     'idx': 1,
#     'name': 'Regional Tåg 1135',
#     'number': '1135',
#     'category': 'JRE',
#     'type': 'JNY',
#     'reachable': True,
#     'waitingState': 'UNDEF',
#     'direction': 'Köpenhamn Österport (Danmark)',
#     'directionFlag': '1',
#     'duration': 'PT3H8M'}]},
#  'calculation': 'INITIAL',
#  'TripStatus': {'detour': True,
#   'economic': True,
#   'convenient': True,
#   'hintCode': 0},
#  'idx': 0,
#  'tripId': 'C-0',
#  'ctxRecon': '¶HKI¶T$A=1@O=Stockholm Centralstation@L=740000001@a=128@$A=1@O=Göteborg Centralstation@L=740000002@a=128@$202501211214$202501211700$JRE  173$$1$$$$$$§T$A=1@O=Göteborg Centralstation@L=740000002@a=128@$A=1@O=Malmö Centralstation@L=740000003@a=128@$202501211740$202501212048$JRE 1135$$1$$$$$$¶KC¶#VE#2#CF#100#CA#0#CM#0#SICT#0#AM#81#AM2#0#RT#4#¶KRCC¶#VE#1#',
#  'duration': 'PT8H34M',
#  'rtDuration': 'PT8H34M',
#  'checksum': '0f0109a1_3',
#  'transferCount': 1}

# %%
example_trip["Origin"]
# Out:
# {'name': 'Stockholm Centralstation',
#  'type': 'ST',
#  'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#  'extId': '740000001',
#  'lon': 18.058151,
#  'lat': 59.330136,
#  'routeIdx': 0,
#  'prognosisType': 'PROGNOSED',
#  'time': '12:14:00',
#  'date': '2025-01-21',
#  'minimumChangeDuration': 'PT20M'}

# %%
example_trip["Destination"]
# Out:
# {'name': 'Malmö Centralstation',
#  'type': 'ST',
#  'id': 'A=1@O=Malmö Centralstation@X=13000910@Y=55609456@U=1@L=740000003@',
#  'extId': '740000003',
#  'lon': 13.00091,
#  'lat': 55.609456,
#  'routeIdx': 12,
#  'prognosisType': 'PROGNOSED',
#  'time': '20:48:00',
#  'date': '2025-01-21',
#  'minimumChangeDuration': 'PT15M'}

# %%
example_trip.keys()
# Out:
# dict_keys(['Origin', 'Destination', 'ServiceDays', 'LegList', 'calculation', 'TripStatus', 'idx', 'tripId', 'ctxRecon', 'duration', 'rtDuration', 'checksum', 'transferCount'])

# %%
len(example_trip["LegList"]["Leg"])
# Out:
# 2

# %%
example_trip["LegList"]["Leg"][0].keys()
# Out:
# dict_keys(['Origin', 'Destination', 'Notes', 'JourneyDetailRef', 'JourneyStatus', 'Product', 'Stops', 'JourneyDetail', 'id', 'idx', 'name', 'number', 'category', 'type', 'reachable', 'waitingState', 'direction', 'directionFlag', 'duration', 'minimumChangeDuration'])

# %%
example_stops = example_trip["LegList"]["Leg"][0]["Stops"]["Stop"]
example_stops
# Out:
# [{'name': 'Stockholm Centralstation',
#   'id': 'A=1@O=Stockholm Centralstation@X=18058151@Y=59330136@U=1@L=740000001@',
#   'extId': '740000001',
#   'routeIdx': 0,
#   'lon': 18.058151,
#   'lat': 59.330136,
#   'depPrognosisType': 'PROGNOSED',
#   'depTime': '12:14:00',
#   'depDate': '2025-01-21',
#   'depDir': 'Göteborg Centralstation',
#   'minimumChangeDuration': 'PT20M'},
#  {'Notes': {'Note': [{'value': 'Stannar endast för påstigande',
#      'key': 'text.realtime.stop.exit.disabled',
#      'type': 'R',
#      'txtN': 'Stannar endast för påstigande'}]},
#   'name': 'Sundbyberg station',
#   'id': 'A=1@O=Sundbyberg station@X=17970938@Y=59361032@U=1@L=740000773@',
#   'extId': '740000773',
#   'routeIdx': 1,
#   'lon': 17.970938,
#   'lat': 59.361032,
#   'depTime': '12:23:00',
#   'depDate': '2025-01-21',
#   'alighting': False,
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Bålsta station (Håbo kn)',
#   'id': 'A=1@O=Bålsta station (Håbo kn)@X=17532813@Y=59568754@U=1@L=740000660@',
#   'extId': '740000660',
#   'routeIdx': 2,
#   'lon': 17.532813,
#   'lat': 59.568754,
#   'depTime': '12:41:00',
#   'depDate': '2025-01-21',
#   'arrTime': '12:41:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Enköping station',
#   'id': 'A=1@O=Enköping station@X=17086741@Y=59644327@U=1@L=740000072@',
#   'extId': '740000072',
#   'routeIdx': 3,
#   'lon': 17.086741,
#   'lat': 59.644327,
#   'depTime': '12:54:00',
#   'depDate': '2025-01-21',
#   'arrTime': '12:54:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT8M'},
#  {'name': 'Västerås Centralstation',
#   'id': 'A=1@O=Västerås Centralstation@X=16551712@Y=59607705@U=1@L=740000099@',
#   'extId': '740000099',
#   'routeIdx': 4,
#   'lon': 16.551712,
#   'lat': 59.607705,
#   'depTime': '13:11:00',
#   'depDate': '2025-01-21',
#   'arrTime': '13:09:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT8M'},
#  {'name': 'Köping station',
#   'id': 'A=1@O=Köping station@X=16004215@Y=59506675@U=1@L=740000167@',
#   'extId': '740000167',
#   'routeIdx': 5,
#   'lon': 16.004215,
#   'lat': 59.506675,
#   'depTime': '13:28:00',
#   'depDate': '2025-01-21',
#   'arrTime': '13:28:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT5M'},
#  {'name': 'Arboga station',
#   'id': 'A=1@O=Arboga station@X=15841061@Y=59397105@U=1@L=740000262@',
#   'extId': '740000262',
#   'routeIdx': 6,
#   'lon': 15.841061,
#   'lat': 59.397105,
#   'depTime': '13:40:00',
#   'depDate': '2025-01-21',
#   'arrTime': '13:39:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT5M'},
#  {'name': 'Örebro Centralstation',
#   'id': 'A=1@O=Örebro Centralstation@X=15211348@Y=59278942@U=1@L=740000133@',
#   'extId': '740000133',
#   'routeIdx': 7,
#   'lon': 15.211348,
#   'lat': 59.278942,
#   'depTime': '14:14:00',
#   'depDate': '2025-01-21',
#   'arrTime': '14:01:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Örebro Södra station',
#   'id': 'A=1@O=Örebro Södra station@X=15202332@Y=59269989@U=1@L=740000361@',
#   'extId': '740000361',
#   'routeIdx': 8,
#   'lon': 15.202332,
#   'lat': 59.269989,
#   'depTime': '14:17:00',
#   'depDate': '2025-01-21',
#   'arrTime': '14:17:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT1H30M'},
#  {'name': 'Kumla station',
#   'id': 'A=1@O=Kumla station@X=15140280@Y=59126377@U=1@L=740000192@',
#   'extId': '740000192',
#   'routeIdx': 9,
#   'lon': 15.14028,
#   'lat': 59.126377,
#   'depTime': '14:27:00',
#   'depDate': '2025-01-21',
#   'arrTime': '14:27:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Hallsberg station',
#   'id': 'A=1@O=Hallsberg station@X=15110391@Y=59066698@U=1@L=740000077@',
#   'extId': '740000077',
#   'routeIdx': 10,
#   'lon': 15.110391,
#   'lat': 59.066698,
#   'depTime': '14:40:00',
#   'depDate': '2025-01-21',
#   'arrTime': '14:35:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Laxå station',
#   'id': 'A=1@O=Laxå station@X=14616658@Y=58989391@U=1@L=740000194@',
#   'extId': '740000194',
#   'routeIdx': 11,
#   'lon': 14.616658,
#   'lat': 58.989391,
#   'depTime': '14:57:00',
#   'depDate': '2025-01-21',
#   'arrTime': '14:57:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Töreboda station',
#   'id': 'A=1@O=Töreboda station@X=14128391@Y=58706024@U=1@L=740000183@',
#   'extId': '740000183',
#   'routeIdx': 12,
#   'lon': 14.128391,
#   'lat': 58.706024,
#   'depTime': '15:20:00',
#   'depDate': '2025-01-21',
#   'arrTime': '15:20:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT8M'},
#  {'name': 'Skövde Centralstation',
#   'id': 'A=1@O=Skövde Centralstation@X=13853195@Y=58390898@U=1@L=740000008@',
#   'extId': '740000008',
#   'routeIdx': 13,
#   'lon': 13.853195,
#   'lat': 58.390898,
#   'depTime': '15:36:00',
#   'depDate': '2025-01-21',
#   'arrTime': '15:35:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Falköping Centralstation',
#   'id': 'A=1@O=Falköping Centralstation@X=13553791@Y=58176101@U=1@L=740000060@',
#   'extId': '740000060',
#   'routeIdx': 14,
#   'lon': 13.553791,
#   'lat': 58.176101,
#   'depTime': '15:52:00',
#   'depDate': '2025-01-21',
#   'arrTime': '15:51:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT8M'},
#  {'name': 'Herrljunga station',
#   'id': 'A=1@O=Herrljunga station@X=13021279@Y=58079188@U=1@L=740000040@',
#   'extId': '740000040',
#   'routeIdx': 15,
#   'lon': 13.021279,
#   'lat': 58.079188,
#   'depTime': '16:06:00',
#   'depDate': '2025-01-21',
#   'arrTime': '16:06:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT8M'},
#  {'name': 'Vårgårda station',
#   'id': 'A=1@O=Vårgårda station@X=12810285@Y=58031204@U=1@L=740000569@',
#   'extId': '740000569',
#   'routeIdx': 16,
#   'lon': 12.810285,
#   'lat': 58.031204,
#   'depTime': '16:14:00',
#   'depDate': '2025-01-21',
#   'arrTime': '16:14:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT10M'},
#  {'name': 'Alingsås station',
#   'id': 'A=1@O=Alingsås station@X=12532491@Y=57926857@U=1@L=740000018@',
#   'extId': '740000018',
#   'routeIdx': 17,
#   'lon': 12.532491,
#   'lat': 57.926857,
#   'depTime': '16:24:00',
#   'depDate': '2025-01-21',
#   'arrTime': '16:24:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT7M'},
#  {'name': 'Göteborg Centralstation',
#   'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@',
#   'extId': '740000002',
#   'routeIdx': 18,
#   'lon': 11.973479,
#   'lat': 57.708895,
#   'arrPrognosisType': 'PROGNOSED',
#   'arrTime': '17:00:00',
#   'arrDate': '2025-01-21',
#   'minimumChangeDuration': 'PT15M'}]

# %%
[{stop.get("name"): stop.get("arrTime")} for stop in example_stops]
# Out:
# [{'Stockholm Centralstation': None},
#  {'Sundbyberg station': None},
#  {'Bålsta station (Håbo kn)': '12:41:00'},
#  {'Enköping station': '12:54:00'},
#  {'Västerås Centralstation': '13:09:00'},
#  {'Köping station': '13:28:00'},
#  {'Arboga station': '13:39:00'},
#  {'Örebro Centralstation': '14:01:00'},
#  {'Örebro Södra station': '14:17:00'},
#  {'Kumla station': '14:27:00'},
#  {'Hallsberg station': '14:35:00'},
#  {'Laxå station': '14:57:00'},
#  {'Töreboda station': '15:20:00'},
#  {'Skövde Centralstation': '15:35:00'},
#  {'Falköping Centralstation': '15:51:00'},
#  {'Herrljunga station': '16:06:00'},
#  {'Vårgårda station': '16:14:00'},
#  {'Alingsås station': '16:24:00'},
#  {'Göteborg Centralstation': '17:00:00'}]

# %% [markdown]
# ## Stop lookup API to find ID

# %%
location = "göteborg"
url = f"https://api.resrobot.se/v2.1/location.name?input={location}&format=json&accessId={API_KEY}"
response = requests.get(url)
result = response.json()
result.keys()
# Out:
# dict_keys(['stopLocationOrCoordLocation', 'TechnicalMessages', 'serverVersion', 'dialectVersion', 'requestId'])

# %%
result["stopLocationOrCoordLocation"]
# Out:
# [{'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '2'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '4'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '8'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '16'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '256'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=GÖTEBORG@X=11973479@Y=57708895@U=1@L=740098001@B=1@p=1737434182@',
#    'extId': '740098001',
#    'name': 'GÖTEBORG',
#    'lon': 11.973479,
#    'lat': 57.708895,
#    'weight': 15426,
#    'products': 222,
#    'meta': True,
#    'minimumChangeDuration': 'PT26M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '2'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '4'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '8'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '16'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Centralstation@X=11973479@Y=57708895@U=1@L=740000002@B=1@p=1737434182@',
#    'extId': '740000002',
#    'name': 'Göteborg Centralstation',
#    'lon': 11.973479,
#    'lat': 57.708895,
#    'weight': 9782,
#    'products': 222,
#    'minimumChangeDuration': 'PT15M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'},
#      'cls': '128'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Sävenäs lokstation@X=12021077@Y=57725993@U=1@L=740016365@B=1@p=1737434182@',
#    'extId': '740016365',
#    'name': 'Göteborg Sävenäs lokstation',
#    'lon': 12.021077,
#    'lat': 57.725993,
#    'weight': 116,
#    'products': 128,
#    'minimumChangeDuration': 'PT5M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'},
#      'cls': '16'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=GÖTEBORG GAMLESTADEN@X=12004411@Y=57729148@U=1@L=740098526@B=1@p=1737434182@',
#    'extId': '740098526',
#    'name': 'GÖTEBORG GAMLESTADEN',
#    'lon': 12.004411,
#    'lat': 57.729148,
#    'weight': 7730,
#    'products': 80,
#    'meta': True,
#    'minimumChangeDuration': 'PT26M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '8'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Korsvägen@X=11986918@Y=57696742@U=1@L=740015578@B=1@p=1737434182@',
#    'extId': '740015578',
#    'name': 'Göteborg Korsvägen',
#    'lon': 11.986918,
#    'lat': 57.696742,
#    'weight': 5668,
#    'products': 200,
#    'minimumChangeDuration': 'PT5M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'}, 'cls': '8'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Kungsportsplatsen@X=11969748@Y=57704023@U=1@L=740016358@B=1@p=1737434182@',
#    'extId': '740016358',
#    'name': 'Göteborg Kungsportsplatsen',
#    'lon': 11.969748,
#    'lat': 57.704023,
#    'weight': 5668,
#    'products': 200,
#    'minimumChangeDuration': 'PT5M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'},
#      'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '256'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Stenpiren@X=11957424@Y=57705803@U=1@L=740072430@B=1@p=1737434182@',
#    'extId': '740072430',
#    'name': 'Göteborg Stenpiren',
#    'lon': 11.957424,
#    'lat': 57.705803,
#    'weight': 4580,
#    'products': 448,
#    'minimumChangeDuration': 'PT5M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'},
#      'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '512'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Eketrägatan@X=11910285@Y=57716275@U=1@L=740025624@B=1@p=1737434182@',
#    'extId': '740025624',
#    'name': 'Göteborg Eketrägatan',
#    'lon': 11.910285,
#    'lat': 57.716275,
#    'weight': 4454,
#    'products': 704,
#    'minimumChangeDuration': 'PT5M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'},
#      'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '512'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Vårväderstorget@X=11893097@Y=57713084@U=1@L=740025707@B=1@p=1737434182@',
#    'extId': '740025707',
#    'name': 'Göteborg Vårväderstorget',
#    'lon': 11.893097,
#    'lat': 57.713084,
#    'weight': 4454,
#    'products': 704,
#    'minimumChangeDuration': 'PT3M'}},
#  {'StopLocation': {'productAtStop': [{'icon': {'res': 'prod_gen'},
#      'cls': '64'},
#     {'icon': {'res': 'prod_gen'}, 'cls': '128'}],
#    'timezoneOffset': 60,
#    'id': 'A=1@O=Göteborg Axel Dahlströms torg@X=11927445@Y=57672435@U=1@L=740025608@B=1@p=1737434182@',
#    'extId': '740025608',
#    'name': 'Göteborg Axel Dahlströms torg',
#    'lon': 11.927445,
#    'lat': 57.672435,
#    'weight': 4429,
#    'products': 192,
#    'minimumChangeDuration': 'PT3M'}}]

# %%
stop_locations = result["stopLocationOrCoordLocation"]
len(stop_locations)
# Out:
# 10

# %%
stop_locations[0]["StopLocation"].keys()
# Out:
# dict_keys(['productAtStop', 'timezoneOffset', 'id', 'extId', 'name', 'lon', 'lat', 'weight', 'products', 'meta', 'minimumChangeDuration'])

# %%
stop_locations[0]["StopLocation"]["name"], stop_locations[0]["StopLocation"]["extId"]
# Out:
# ('GÖTEBORG', '740098001')

# %%
print(f"{'Stop':<50} extId")
for stop_location in stop_locations:
    stop = stop_location["StopLocation"]
    print(f"{stop["name"]:<50} {stop["extId"]}")
# Out:
# Stop                                               extId
# GÖTEBORG                                           740098001
# Göteborg Centralstation                            740000002
# Göteborg Sävenäs lokstation                        740016365
# GÖTEBORG GAMLESTADEN                               740098526
# Göteborg Korsvägen                                 740015578
# Göteborg Kungsportsplatsen                         740016358
# Göteborg Stenpiren                                 740072430
# Göteborg Eketrägatan                               740025624
# Göteborg Vårväderstorget                           740025707
# Göteborg Axel Dahlströms torg                      740025608

# %%
def access_id_from_location(location):
    url = f"https://api.resrobot.se/v2.1/location.name?input={location}&format=json&accessId={API_KEY}"

    try:
        response = requests.get(url)
        result = response.json()

        print(f"{'Name':<50} extId")

        for stop in result.get("stopLocationOrCoordLocation"):
            stop_data = next(iter(stop.values()))

            # returns None if extId doesn't exist
            if stop_data.get("extId"):
                print(f"{stop_data['name']:<50} {stop_data['extId']}")

    except requests.exceptions.RequestException as err:
        print(f"Network or HTTP error: {err}")

access_id_from_location("malm")
# Out:
# Name                                               extId
# Malm (Gullspång kn)                                740062061
# Malmö Centralstation                               740000003
# Malmö Triangeln station                            740001587
# Malmö Hyllie station                               740001586
# Malmö Svågertorp station                           740001546
# MALMÖ                                              740098548
# Malmö Persborg station                             740001486
# Malmö Rosengård station                            740001621
# Malmö Östervärn station                            740001483
# Malmö Fosieby station                              740001553

# %%
access_id_from_location("onsala")
# Out:
# Name                                               extId
# Onsala kyrka (Kungsbacka kn)                       740000092
# Onsala vårdcentral (Kungsbacka kn)                 740061484

# %%
access_id_from_location("karlstd")
# Out:
# Name                                               extId
# Karlstad Centralstation                            740000070
# Karlskrona Centralstation                          740000230
# KARLSTAD                                           740098025
# Karlstad Busstationen                              740010760
# Karlstorpsporten (Trollhättan kn)                  740043161
# Karlstad, Älvdalsgatan                             740073274
# Karlstad, Bergvik Coop                             740022229
# Karlstad, Bergvik Maxi                             740057556
# Karlstad, Blåljusbyn                               740057772
# Karlstad, Brigadmuseet                             740057652

# %% [markdown]
# ## Time tables

# %%
# korsvägen
stop_id=740015578
url = f"https://api.resrobot.se/v2.1/departureBoard?id={stop_id}&format=json&accessId={API_KEY}"

response = requests.get(url)
results = response.json()
results.keys()
# Out:
# dict_keys(['Departure', 'TechnicalMessages', 'serverVersion', 'dialectVersion', 'planRtTs', 'requestId'])

# %%
import pandas as pd 

df_timetable = pd.DataFrame(results["Departure"])
df_timetable.head()
# Out:
#                    JourneyDetailRef JourneyStatus  \
# 0     {'ref': '1|293|0|1|21012025'}             P
# 1  {'ref': '1|156094|4|1|21012025'}             P
# 2   {'ref': '1|11600|3|1|21012025'}             P
# 3  {'ref': '1|112779|4|1|21012025'}             P
# 4  {'ref': '1|112957|3|1|21012025'}             P
#
#                                        ProductAtStop  \
# 0  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 1  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 2  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 3  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
# 4  {'icon': {'res': 'prod_gen'}, 'operatorInfo': ...
#
#                                              Product  \
# 0  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 1  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 2  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 3  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
# 4  [{'icon': {'res': 'prod_gen'}, 'operatorInfo':...
#
#                                                Notes                    name  \
# 0  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...    Länstrafik - Buss X4
# 1  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...  Länstrafik - Spårväg 6
# 2  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...    Länstrafik - Buss 61
# 3  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...  Länstrafik - Spårväg 2
# 4  {'Note': [{'value': 'Lag 2015:953 tillämpas', ...  Länstrafik - Spårväg 2
#
#   type                   stop  \
# 0   ST     Göteborg Korsvägen
# 1   ST  Göteborg Scandinavium
# 2   ST     Göteborg Korsvägen
# 3   ST     Göteborg Korsvägen
# 4   ST     Göteborg Korsvägen
#
#                                               stopid  stopExtId        lon  \
# 0  A=1@O=Göteborg Korsvägen@X=11986918@Y=57696742...  740015578  11.986918
# 1  A=1@O=Göteborg Scandinavium@X=11985875@Y=57700...  740025681  11.985875
# 2  A=1@O=Göteborg Korsvägen@X=11986918@Y=57696742...  740015578  11.986918
# 3  A=1@O=Göteborg Korsvägen@X=11986918@Y=57696742...  740015578  11.986918
# 4  A=1@O=Göteborg Korsvägen@X=11986918@Y=57696742...  740015578  11.986918
#
#          lat      time        date  reachable                      direction  \
# 0  57.696742  12:32:00  2025-01-21       True       Höga hallar (Härryda kn)
# 1  57.700445  12:32:00  2025-01-21       True       Göteborg Varmfrontsgatan
# 2  57.696742  12:33:00  2025-01-21       True       Masthugget (Göteborg kn)
# 3  57.696742  12:33:00  2025-01-21       True             Mölndals Innerstad
# 4  57.696742  12:33:00  2025-01-21       True  Göteborg Axel Dahlströms torg
#
#   directionFlag
# 0             1
# 1             2
# 2             1
# 3             1
# 4             2

# %%
df_timetable.columns
# Out:
# Index(['JourneyDetailRef', 'JourneyStatus', 'ProductAtStop', 'Product',
#        'Notes', 'name', 'type', 'stop', 'stopid', 'stopExtId', 'lon', 'lat',
#        'time', 'date', 'reachable', 'direction', 'directionFlag'],
#       dtype='object')

# %%
df_timetable_cleaned = df_timetable[["name", "stop", "lon", "lat", "direction", "date", "time"]]
df_timetable_cleaned
# Out:
#                        name                   stop        lon        lat  \
# 0      Länstrafik - Buss X4     Göteborg Korsvägen  11.986918  57.696742
# 1    Länstrafik - Spårväg 6  Göteborg Scandinavium  11.985875  57.700445
# 2      Länstrafik - Buss 61     Göteborg Korsvägen  11.986918  57.696742
# 3    Länstrafik - Spårväg 2     Göteborg Korsvägen  11.986918  57.696742
# 4    Länstrafik - Spårväg 2     Göteborg Korsvägen  11.986918  57.696742
# ..                      ...                    ...        ...        ...
# 178    Länstrafik - Buss 18     Göteborg Korsvägen  11.986918  57.696742
# 179  Länstrafik - Spårväg 6  Göteborg Scandinavium  11.985875  57.700445
# 180  Länstrafik - Spårväg 2     Göteborg Korsvägen  11.986918  57.696742
# 181  Länstrafik - Spårväg 2     Göteborg Korsvägen  11.986918  57.696742
# 182  Länstrafik - Spårväg 6  Göteborg Scandinavium  11.985875  57.700445
#
#                               direction        date      time
# 0              Höga hallar (Härryda kn)  2025-01-21  12:32:00
# 1              Göteborg Varmfrontsgatan  2025-01-21  12:32:00
# 2              Masthugget (Göteborg kn)  2025-01-21  12:33:00
# 3                    Mölndals Innerstad  2025-01-21  12:33:00
# 4         Göteborg Axel Dahlströms torg  2025-01-21  12:33:00
# ..                                  ...         ...       ...
# 178       Körkarlens gata (Göteborg kn)  2025-01-21  13:31:00
# 179  Kortedala Aprilgatan (Göteborg kn)  2025-01-21  13:31:00
# 180                  Mölndals Innerstad  2025-01-21  13:32:00
# 181       Göteborg Axel Dahlströms torg  2025-01-21  13:32:00
# 182            Göteborg Varmfrontsgatan  2025-01-21  13:32:00
#
# [183 rows x 7 columns]

# %%
df_timetable_cleaned["name"].value_counts()
# Out:
# name
# Länstrafik - Spårväg 2    26
# Länstrafik - Spårväg 6    25
# Länstrafik - Spårväg 8    24
# Länstrafik - Buss X4      23
# Länstrafik - Buss 18      16
# Länstrafik - Spårväg 5    12
# Länstrafik - Buss 61      12
# Länstrafik - Buss 63      12
# Länstrafik - Spårväg 4    12
# Länstrafik - Buss RÖD      8
# Länstrafik - Buss 758      4
# Länstrafik - Buss 100      3
# Flygtransfer - Buss .      2
# Länstrafik - Buss 101      2
# Länstrafik - Buss 300      2
# Name: count, dtype: int64
